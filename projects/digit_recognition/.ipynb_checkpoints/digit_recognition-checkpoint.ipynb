# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Deep Learning
# ## Project: Build a Digit Recognition Program
#
# In this notebook, a template is provided for you to implement your functionality in stages which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission, if necessary. Sections that begin with **'Implementation'** in the header indicate where you should begin your implementation for your project. Note that some sections of implementation are optional, and will be marked with **'Optional'** in the header.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ----
# ## Step 1: Design and Test a Model Architecture
# Design and implement a deep learning model that learns to recognize sequences of digits. Train the model using synthetic data generated by concatenating character images from [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) or [MNIST](http://yann.lecun.com/exdb/mnist/). To produce a synthetic sequence of digits for testing, you can for example limit yourself to sequences up to five digits, and use five classifiers on top of your deep network. You would have to incorporate an additional ‘blank’ character to account for shorter number sequences.
#
# There are various aspects to consider when thinking about this problem:
# - Your model can be derived from a deep neural net or a convolutional network.
# - You could experiment sharing or not the weights between the softmax classifiers.
# - You can also use a recurrent network in your deep neural net to replace the classification layers and directly emit the sequence of digits one-at-a-time.
#
# You can use ** Keras ** to implement your model. Read more at [keras.io](https://keras.io/).
#
# Here is an example of a [published baseline model on this problem](http://static.googleusercontent.com/media/research.google.com/en//pubs/archive/42241.pdf). ([video](https://www.youtube.com/watch?v=vGPI_JvLoN0)). You are not expected to model your architecture precisely using this model nor get the same performance levels, but this is more to show an exampe of an approach used to solve this particular problem. We encourage you to try out different architectures for yourself and see what works best for you. Here is a useful [forum post](https://discussions.udacity.com/t/goodfellow-et-al-2013-architecture/202363) discussing the architecture as described in the paper and here is [another one](https://discussions.udacity.com/t/what-loss-function-to-use-for-multi-digit-svhn-training/176897) discussing the loss function.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your code implementation goes here.
### Feel free to use as many code cells as needed.

from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf

mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)

test_valid_size = 256
num_labels = 10
hidden_nodes = 1024
height = 28
width = 28
epochs = 20
batch_size = 128
learning_rate = 0.001
dropout = 0.5
keep_prob = tf.placeholder(tf.float32)

x = tf.placeholder("float",[None,width,height,1])
y = tf.placeholder("float",[None,num_labels])
x_flat = tf.reshape(x,[-1, height*width])

weights = {
    'hidden_layer': tf.Variable(tf.truncated_normal([width*height,hidden_nodes])),\
    'output': tf.Variable(tf.truncated_normal([hidden_nodes, num_labels]))
}

biases = {
    'hidden_layer': tf.Variable(tf.zeros(hidden_nodes)),\
    'output': tf.Variable(tf.zeros(num_labels))
}

hidden_layer = tf.add(tf.matmul(x_flat,weights['hidden_layer']),biases['hidden_layer'])
hidden_layer = tf.nn.relu(hidden_layer)
hidden_layer = tf.nn.dropout(hidden_layer, keep_prob)
logits = tf.add(tf.matmul(hidden_layer,weights['output']),biases['output'])

cost = tf.reduce_mean(\
                     tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
.minimize(cost)

correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

init = tf.global_variables_initializer()

with tf.Session() as session:
    session.run(init)
    
    for epoch in range(epochs):
        total_batch = int(mnist.train.num_examples/batch_size)
        for i in range(total_batch):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            session.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
            loss = session.run(cost, feed_dict = {x: batch_x, y: batch_y, keep_prob: 1.})
            valid_acc = session.run(accuracy, feed_dict={x: mnist.validation.images[:test_valid_size],
                                                     y: mnist.validation.labels[:test_valid_size],
                                                     keep_prob: 1.})
            print("Epoch " + str((epoch+1)) + " at batch " + str(i) + " accuracy is : " + str(valid_acc))
            print("Epoch " + str((epoch+1)) + " loss is : " + str(loss))
    
    test_acc = session.run(accuracy, feed_dict={x: mnist.test.images[:test_valid_size],
                                              y: mnist.test.labels[:test_valid_size],
                                              keep_prob: 1.})
    print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz
# Epoch 1 at batch 0 accuracy is : 0.0664062
# Epoch 1 loss is : 217.99
# Epoch 1 at batch 1 accuracy is : 0.0664062
# Epoch 1 loss is : 216.481
# Epoch 1 at batch 2 accuracy is : 0.0664062
# Epoch 1 loss is : 213.788
# Epoch 1 at batch 3 accuracy is : 0.0664062
# Epoch 1 loss is : 250.247
# Epoch 1 at batch 4 accuracy is : 0.0664062
# Epoch 1 loss is : 219.384
# Epoch 1 at batch 5 accuracy is : 0.078125
# Epoch 1 loss is : 227.925
# Epoch 1 at batch 6 accuracy is : 0.0820312
# Epoch 1 loss is : 208.101
# Epoch 1 at batch 7 accuracy is : 0.0820312
# Epoch 1 loss is : 213.17
# Epoch 1 at batch 8 accuracy is : 0.0898438
# Epoch 1 loss is : 218.411
# Epoch 1 at batch 9 accuracy is : 0.0898438
# Epoch 1 loss is : 209.055
# Epoch 1 at batch 10 accuracy is : 0.09375
# Epoch 1 loss is : 200.235
# Epoch 1 at batch 11 accuracy is : 0.09375
# Epoch 1 loss is : 195.95
# Epoch 1 at batch 12 accuracy is : 0.0976562
# Epoch 1 loss is : 188.508
# Epoch 1 at batch 13 accuracy is : 0.0976562
# Epoch 1 loss is : 165.34
# Epoch 1 at batch 14 accuracy is : 0.0976562
# Epoch 1 loss is : 176.022
# Epoch 1 at batch 15 accuracy is : 0.101562
# Epoch 1 loss is : 161.954
# Epoch 1 at batch 16 accuracy is : 0.101562
# Epoch 1 loss is : 171.651
# Epoch 1 at batch 17 accuracy is : 0.109375
# Epoch 1 loss is : 156.54
# Epoch 1 at batch 18 accuracy is : 0.117188
# Epoch 1 loss is : 163.22
# Epoch 1 at batch 19 accuracy is : 0.125
# Epoch 1 loss is : 171.387
# Epoch 1 at batch 20 accuracy is : 0.121094
# Epoch 2 loss is : 20.482
# Epoch 2 at batch 252 accuracy is : 0.753906
# Epoch 2 loss is : 24.7644
# Epoch 2 at batch 253 accuracy is : 0.753906
# Epoch 2 loss is : 26.6425
# Epoch 2 at batch 254 accuracy is : 0.757812
# Epoch 2 loss is : 25.8471
# Epoch 2 at batch 255 accuracy is : 0.757812
# Epoch 2 loss is : 20.5352
# Epoch 2 at batch 256 accuracy is : 0.757812
# Epoch 2 loss is : 28.5825
# Epoch 2 at batch 257 accuracy is : 0.757812
# Epoch 2 loss is : 23.9856
# Epoch 2 at batch 258 accuracy is : 0.757812
# Epoch 2 loss is : 23.111
# Epoch 2 at batch 259 accuracy is : 0.757812
# Epoch 2 loss is : 24.0015
# ...
# Epoch 20 at batch 207 accuracy is : 0.898438
# Epoch 20 loss is : 11.7051
# Epoch 20 at batch 208 accuracy is : 0.898438
# Epoch 20 loss is : 5.55282
# Epoch 20 at batch 209 accuracy is : 0.898438
# Epoch 20 loss is : 2.87513
# Epoch 20 at batch 210 accuracy is : 0.898438
# Epoch 20 loss is : 11.625
# Epoch 20 at batch 211 accuracy is : 0.898438
# Epoch 20 loss is : 7.14502
# Epoch 20 at batch 212 accuracy is : 0.898438
# Epoch 20 loss is : 16.7976
# Epoch 20 at batch 213 accuracy is : 0.898438
# Epoch 20 loss is : 16.6652
# Epoch 20 at batch 214 accuracy is : 0.898438
# Epoch 20 loss is : 15.0218
# Epoch 20 at batch 215 accuracy is : 0.898438
# Epoch 20 loss is : 11.6882
# Epoch 20 at batch 216 accuracy is : 0.898438
# Epoch 20 loss is : 16.7755
# Epoch 20 at batch 217 accuracy is : 0.898438
# Epoch 20 loss is : 8.13682
# Epoch 20 at batch 218 accuracy is : 0.898438
# Epoch 20 loss is : 3.07908
# Epoch 20 at batch 219 accuracy is : 0.898438
# Epoch 20 loss is : 16.0796
# Epoch 20 at batch 220 accuracy is : 0.898438
# Epoch 20 loss is : 7.30412
# Epoch 20 at batch 221 accuracy is : 0.898438
# Epoch 20 loss is : 11.6624
# Epoch 20 at batch 222 accuracy is : 0.898438
# Epoch 20 loss is : 5.36269
# Epoch 20 at batch 223 accuracy is : 0.898438
# Epoch 20 loss is : 6.88293
# Epoch 20 at batch 224 accuracy is : 0.898438
# Epoch 20 loss is : 18.8385
# Epoch 20 at batch 225 accuracy is : 0.898438
# Epoch 20 loss is : 13.4281
# Epoch 20 at batch 226 accuracy is : 0.898438
# Epoch 20 loss is : 10.3485
# Epoch 20 at batch 227 accuracy is : 0.898438
# Epoch 20 loss is : 7.13229
# Epoch 20 at batch 228 accuracy is : 0.898438
# Epoch 20 loss is : 9.26009
# Epoch 20 at batch 229 accuracy is : 0.898438
# Epoch 20 loss is : 11.4317
# Epoch 20 at batch 230 accuracy is : 0.898438
# Epoch 20 loss is : 11.4248
# Epoch 20 at batch 231 accuracy is : 0.898438
# Epoch 20 loss is : 7.94097
# Epoch 20 at batch 232 accuracy is : 0.898438
# Epoch 20 loss is : 7.51098
# Epoch 20 at batch 233 accuracy is : 0.898438
# Epoch 20 loss is : 10.0621
# Epoch 20 at batch 234 accuracy is : 0.898438
# Epoch 20 loss is : 18.9195
# Epoch 20 at batch 235 accuracy is : 0.898438
# Epoch 20 loss is : 10.6964
# Epoch 20 at batch 236 accuracy is : 0.898438
# Epoch 20 loss is : 10.8076
# Epoch 20 at batch 237 accuracy is : 0.898438
# Epoch 20 loss is : 7.89758
# Epoch 20 at batch 238 accuracy is : 0.898438
# Epoch 20 loss is : 7.93158
# Epoch 20 at batch 239 accuracy is : 0.898438
# Epoch 20 loss is : 5.26879
# Epoch 20 at batch 240 accuracy is : 0.898438
# Epoch 20 loss is : 17.5286
# Epoch 20 at batch 241 accuracy is : 0.898438
# Epoch 20 loss is : 8.29215
# Epoch 20 at batch 242 accuracy is : 0.898438
# Epoch 20 loss is : 18.8501
# Epoch 20 at batch 243 accuracy is : 0.898438
# Epoch 20 loss is : 7.57505
# Epoch 20 at batch 244 accuracy is : 0.898438
# Epoch 20 loss is : 15.3411
# Epoch 20 at batch 245 accuracy is : 0.898438
# Epoch 20 loss is : 6.48714
# Epoch 20 at batch 246 accuracy is : 0.898438
# Epoch 20 loss is : 13.1172
# Epoch 20 at batch 247 accuracy is : 0.898438
# Epoch 20 loss is : 12.7519
# Epoch 20 at batch 248 accuracy is : 0.898438
# Epoch 20 loss is : 9.58707
# Epoch 20 at batch 249 accuracy is : 0.898438
# Epoch 20 loss is : 10.8805
# Epoch 20 at batch 250 accuracy is : 0.898438
# Epoch 20 loss is : 8.45959
# Epoch 20 at batch 251 accuracy is : 0.898438
# Epoch 20 loss is : 8.44353
# Epoch 20 at batch 252 accuracy is : 0.898438
# Epoch 20 loss is : 9.12741
# Epoch 20 at batch 253 accuracy is : 0.898438
# Epoch 20 loss is : 12.2309
# Epoch 20 at batch 254 accuracy is : 0.898438
# Epoch 20 loss is : 12.4341
# Epoch 20 at batch 255 accuracy is : 0.898438
# Epoch 20 loss is : 15.7101
# Epoch 20 at batch 256 accuracy is : 0.898438
# Epoch 20 loss is : 5.57671
# Epoch 20 at batch 257 accuracy is : 0.898438
# Epoch 20 loss is : 8.10101
# Epoch 20 at batch 258 accuracy is : 0.898438
# Epoch 20 loss is : 6.35486
# Epoch 20 at batch 259 accuracy is : 0.898438
# Epoch 20 loss is : 5.13411
# Epoch 20 at batch 260 accuracy is : 0.898438
# Epoch 20 loss is : 13.0521
# Epoch 20 at batch 261 accuracy is : 0.898438
# Epoch 20 loss is : 6.25493
# Epoch 20 at batch 262 accuracy is : 0.898438
# Epoch 20 loss is : 8.10672
# Epoch 20 at batch 263 accuracy is : 0.898438
# Epoch 20 loss is : 7.96834
# Epoch 20 at batch 264 accuracy is : 0.898438
# Epoch 20 loss is : 13.1668
# Epoch 20 at batch 265 accuracy is : 0.898438
# Epoch 20 loss is : 11.5548
# Epoch 20 at batch 266 accuracy is : 0.898438
# Epoch 20 loss is : 10.0892
# Epoch 20 at batch 267 accuracy is : 0.898438
# Epoch 20 loss is : 3.91307
# Epoch 20 at batch 268 accuracy is : 0.898438
# Epoch 20 loss is : 6.4682
# Epoch 20 at batch 269 accuracy is : 0.898438
# Epoch 20 loss is : 7.20095
# Epoch 20 at batch 270 accuracy is : 0.898438
# Epoch 20 loss is : 9.8911
# Epoch 20 at batch 271 accuracy is : 0.898438
# Epoch 20 loss is : 10.3984
# Epoch 20 at batch 272 accuracy is : 0.898438
# Epoch 20 loss is : 8.60101
# Epoch 20 at batch 273 accuracy is : 0.898438
# Epoch 20 loss is : 6.83296
# Epoch 20 at batch 274 accuracy is : 0.898438
# Epoch 20 loss is : 6.52179
# Epoch 20 at batch 275 accuracy is : 0.898438
# Epoch 20 loss is : 7.21133
# Epoch 20 at batch 276 accuracy is : 0.898438
# Epoch 20 loss is : 16.4224
# Epoch 20 at batch 277 accuracy is : 0.898438
# Epoch 20 loss is : 5.4416
# Epoch 20 at batch 278 accuracy is : 0.898438
# Epoch 20 loss is : 10.5579
# Epoch 20 at batch 279 accuracy is : 0.898438
# Epoch 20 loss is : 15.0605
# Epoch 20 at batch 280 accuracy is : 0.898438
# Epoch 20 loss is : 7.24492
# Epoch 20 at batch 281 accuracy is : 0.898438
# Epoch 20 loss is : 3.95567
# Epoch 20 at batch 282 accuracy is : 0.898438
# Epoch 20 loss is : 7.49757
# Epoch 20 at batch 283 accuracy is : 0.898438
# Epoch 20 loss is : 8.09185
# Epoch 20 at batch 284 accuracy is : 0.898438
# Epoch 20 loss is : 5.36359
# Epoch 20 at batch 285 accuracy is : 0.898438
# Epoch 20 loss is : 7.50139
# Epoch 20 at batch 286 accuracy is : 0.898438
# Epoch 20 loss is : 12.1047
# Epoch 20 at batch 287 accuracy is : 0.898438
# Epoch 20 loss is : 7.58931
# Epoch 20 at batch 288 accuracy is : 0.898438
# Epoch 20 loss is : 3.38258
# Epoch 20 at batch 289 accuracy is : 0.898438
# Epoch 20 loss is : 7.18001
# Epoch 20 at batch 290 accuracy is : 0.898438
# Epoch 20 loss is : 7.27965
# Epoch 20 at batch 291 accuracy is : 0.898438
# Epoch 20 loss is : 7.19551
# Epoch 20 at batch 292 accuracy is : 0.898438
# Epoch 20 loss is : 6.37935
# Epoch 20 at batch 293 accuracy is : 0.898438
# Epoch 20 loss is : 20.3078
# Epoch 20 at batch 294 accuracy is : 0.898438
# Epoch 20 loss is : 6.90518
# Epoch 20 at batch 295 accuracy is : 0.898438
# Epoch 20 loss is : 7.90919
# Epoch 20 at batch 296 accuracy is : 0.898438
# Epoch 20 loss is : 7.90107
# Epoch 20 at batch 297 accuracy is : 0.898438
# Epoch 20 loss is : 8.08846
# Epoch 20 at batch 298 accuracy is : 0.898438
# Epoch 20 loss is : 10.3287
# Epoch 20 at batch 299 accuracy is : 0.898438
# Epoch 20 loss is : 8.34476
# Epoch 20 at batch 300 accuracy is : 0.898438
# Epoch 20 loss is : 7.85785
# Epoch 20 at batch 301 accuracy is : 0.898438
# Epoch 20 loss is : 10.7285
# Epoch 20 at batch 302 accuracy is : 0.898438
# Epoch 20 loss is : 14.4996
# Epoch 20 at batch 303 accuracy is : 0.898438
# Epoch 20 loss is : 6.01124
# Epoch 20 at batch 304 accuracy is : 0.898438
# Epoch 20 loss is : 8.17561
# Epoch 20 at batch 305 accuracy is : 0.898438
# Epoch 20 loss is : 9.24713
# Epoch 20 at batch 306 accuracy is : 0.898438
# Epoch 20 loss is : 4.05577
# Epoch 20 at batch 307 accuracy is : 0.898438
# Epoch 20 loss is : 16.0974
# Epoch 20 at batch 308 accuracy is : 0.898438
# Epoch 20 loss is : 9.37325
# Epoch 20 at batch 309 accuracy is : 0.898438
# Epoch 20 loss is : 8.39573
# Epoch 20 at batch 310 accuracy is : 0.898438
# Epoch 20 loss is : 8.77144
# Epoch 20 at batch 311 accuracy is : 0.898438
# Epoch 20 loss is : 10.0726
# Epoch 20 at batch 312 accuracy is : 0.898438
# Epoch 20 loss is : 7.31029
# Epoch 20 at batch 313 accuracy is : 0.898438
# Epoch 20 loss is : 3.77746
# Epoch 20 at batch 314 accuracy is : 0.898438
# Epoch 20 loss is : 9.63124
# Epoch 20 at batch 315 accuracy is : 0.898438
# Epoch 20 loss is : 5.31097
# Epoch 20 at batch 316 accuracy is : 0.898438
# Epoch 20 loss is : 6.94751
# Epoch 20 at batch 317 accuracy is : 0.898438
# Epoch 20 loss is : 9.44528
# Epoch 20 at batch 318 accuracy is : 0.898438
# Epoch 20 loss is : 8.02257
# Epoch 20 at batch 319 accuracy is : 0.898438
# Epoch 20 loss is : 9.11144
# Epoch 20 at batch 320 accuracy is : 0.898438
# Epoch 20 loss is : 12.9057
# Epoch 20 at batch 321 accuracy is : 0.898438
# Epoch 20 loss is : 7.82547
# Epoch 20 at batch 322 accuracy is : 0.898438
# Epoch 20 loss is : 10.5826
# Epoch 20 at batch 323 accuracy is : 0.898438
# Epoch 20 loss is : 13.9078
# Epoch 20 at batch 324 accuracy is : 0.898438
# Epoch 20 loss is : 8.56974
# Epoch 20 at batch 325 accuracy is : 0.898438
# Epoch 20 loss is : 9.89122
# Epoch 20 at batch 326 accuracy is : 0.898438
# Epoch 20 loss is : 7.86067
# Epoch 20 at batch 327 accuracy is : 0.898438
# Epoch 20 loss is : 8.70092
# Epoch 20 at batch 328 accuracy is : 0.898438
# Epoch 20 loss is : 6.83891
# Epoch 20 at batch 329 accuracy is : 0.898438
# Epoch 20 loss is : 13.3665
# Epoch 20 at batch 330 accuracy is : 0.898438
# Epoch 20 loss is : 10.0556
# Epoch 20 at batch 331 accuracy is : 0.898438
# Epoch 20 loss is : 17.9604
# Epoch 20 at batch 332 accuracy is : 0.898438
# Epoch 20 loss is : 8.76841
# Epoch 20 at batch 333 accuracy is : 0.898438
# Epoch 20 loss is : 6.73123
# Epoch 20 at batch 334 accuracy is : 0.898438
# Epoch 20 loss is : 9.52411
# Epoch 20 at batch 335 accuracy is : 0.898438
# Epoch 20 loss is : 9.28121
# Epoch 20 at batch 336 accuracy is : 0.898438
# Epoch 20 loss is : 15.4768
# Epoch 20 at batch 337 accuracy is : 0.898438
# Epoch 20 loss is : 11.5734
# Epoch 20 at batch 338 accuracy is : 0.898438
# Epoch 20 loss is : 5.08939
# Epoch 20 at batch 339 accuracy is : 0.898438
# Epoch 20 loss is : 13.976
# Epoch 20 at batch 340 accuracy is : 0.898438
# Epoch 20 loss is : 7.95378
# Epoch 20 at batch 341 accuracy is : 0.898438
# Epoch 20 loss is : 6.81002
# Epoch 20 at batch 342 accuracy is : 0.898438
# Epoch 20 loss is : 6.34491
# Epoch 20 at batch 343 accuracy is : 0.898438
# Epoch 20 loss is : 7.64505
# Epoch 20 at batch 344 accuracy is : 0.898438
# Epoch 20 loss is : 7.89686
# Epoch 20 at batch 345 accuracy is : 0.898438
# Epoch 20 loss is : 6.14522
# Epoch 20 at batch 346 accuracy is : 0.898438
# Epoch 20 loss is : 5.02026
# Epoch 20 at batch 347 accuracy is : 0.898438
# Epoch 20 loss is : 10.1861
# Epoch 20 at batch 348 accuracy is : 0.898438
# Epoch 20 loss is : 12.0827
# Epoch 20 at batch 349 accuracy is : 0.898438
# Epoch 20 loss is : 2.3884
# Epoch 20 at batch 350 accuracy is : 0.898438
# Epoch 20 loss is : 4.86058
# Epoch 20 at batch 351 accuracy is : 0.898438
# Epoch 20 loss is : 8.30173
# Epoch 20 at batch 352 accuracy is : 0.898438
# Epoch 20 loss is : 11.5786
# Epoch 20 at batch 353 accuracy is : 0.898438
# Epoch 20 loss is : 15.1446
# Epoch 20 at batch 354 accuracy is : 0.898438
# Epoch 20 loss is : 14.9604
# Epoch 20 at batch 355 accuracy is : 0.898438
# Epoch 20 loss is : 7.21181
# Epoch 20 at batch 356 accuracy is : 0.898438
# Epoch 20 loss is : 7.91549
# Epoch 20 at batch 357 accuracy is : 0.898438
# Epoch 20 loss is : 9.89186
# Epoch 20 at batch 358 accuracy is : 0.898438
# Epoch 20 loss is : 6.04033
# Epoch 20 at batch 359 accuracy is : 0.898438
# Epoch 20 loss is : 5.53339
# Epoch 20 at batch 360 accuracy is : 0.898438
# Epoch 20 loss is : 10.7247
# Epoch 20 at batch 361 accuracy is : 0.898438
# Epoch 20 loss is : 15.7367
# Epoch 20 at batch 362 accuracy is : 0.898438
# Epoch 20 loss is : 6.31565
# Epoch 20 at batch 363 accuracy is : 0.898438
# Epoch 20 loss is : 14.1474
# Epoch 20 at batch 364 accuracy is : 0.898438
# Epoch 20 loss is : 10.5695
# Epoch 20 at batch 365 accuracy is : 0.898438
# Epoch 20 loss is : 4.34238
# Epoch 20 at batch 366 accuracy is : 0.898438
# Epoch 20 loss is : 6.32178
# Epoch 20 at batch 367 accuracy is : 0.898438
# Epoch 20 loss is : 7.21303
# Epoch 20 at batch 368 accuracy is : 0.898438
# Epoch 20 loss is : 8.199
# Epoch 20 at batch 369 accuracy is : 0.898438
# Epoch 20 loss is : 4.59772
# Epoch 20 at batch 370 accuracy is : 0.898438
# Epoch 20 loss is : 8.27994
# Epoch 20 at batch 371 accuracy is : 0.898438
# Epoch 20 loss is : 3.27378
# Epoch 20 at batch 372 accuracy is : 0.898438
# Epoch 20 loss is : 11.79
# Epoch 20 at batch 373 accuracy is : 0.898438
# Epoch 20 loss is : 7.74598
# Epoch 20 at batch 374 accuracy is : 0.898438
# Epoch 20 loss is : 15.5687
# Epoch 20 at batch 375 accuracy is : 0.898438
# Epoch 20 loss is : 9.10844
# Epoch 20 at batch 376 accuracy is : 0.898438
# Epoch 20 loss is : 9.08764
# Epoch 20 at batch 377 accuracy is : 0.898438
# Epoch 20 loss is : 7.581
# Epoch 20 at batch 378 accuracy is : 0.898438
# Epoch 20 loss is : 13.0949
# Epoch 20 at batch 379 accuracy is : 0.898438
# Epoch 20 loss is : 12.0354
# Epoch 20 at batch 380 accuracy is : 0.898438
# Epoch 20 loss is : 9.37904
# Epoch 20 at batch 381 accuracy is : 0.898438
# Epoch 20 loss is : 7.99987
# Epoch 20 at batch 382 accuracy is : 0.898438
# Epoch 20 loss is : 14.4515
# Epoch 20 at batch 383 accuracy is : 0.898438
# Epoch 20 loss is : 10.9052
# Epoch 20 at batch 384 accuracy is : 0.898438
# Epoch 20 loss is : 8.83334
# Epoch 20 at batch 385 accuracy is : 0.898438
# Epoch 20 loss is : 9.0722
# Epoch 20 at batch 386 accuracy is : 0.898438
# Epoch 20 loss is : 11.6357
# Epoch 20 at batch 387 accuracy is : 0.898438
# Epoch 20 loss is : 7.08715
# Epoch 20 at batch 388 accuracy is : 0.898438
# Epoch 20 loss is : 3.98982
# Epoch 20 at batch 389 accuracy is : 0.898438
# Epoch 20 loss is : 11.6398
# Epoch 20 at batch 390 accuracy is : 0.898438
# Epoch 20 loss is : 9.91501
# Epoch 20 at batch 391 accuracy is : 0.898438
# Epoch 20 loss is : 11.5139
# Epoch 20 at batch 392 accuracy is : 0.898438
# Epoch 20 loss is : 9.12291
# Epoch 20 at batch 393 accuracy is : 0.898438
# Epoch 20 loss is : 6.34828
# Epoch 20 at batch 394 accuracy is : 0.898438
# Epoch 20 loss is : 19.247
# Epoch 20 at batch 395 accuracy is : 0.898438
# Epoch 20 loss is : 11.1242
# Epoch 20 at batch 396 accuracy is : 0.898438
# Epoch 20 loss is : 12.8655
# Epoch 20 at batch 397 accuracy is : 0.898438
# Epoch 20 loss is : 9.53891
# Epoch 20 at batch 398 accuracy is : 0.898438
# Epoch 20 loss is : 13.6871
# Epoch 20 at batch 399 accuracy is : 0.898438
# Epoch 20 loss is : 7.47927
# Epoch 20 at batch 400 accuracy is : 0.898438
# Epoch 20 loss is : 11.0678
# Epoch 20 at batch 401 accuracy is : 0.898438
# Epoch 20 loss is : 5.64793
# Epoch 20 at batch 402 accuracy is : 0.898438
# Epoch 20 loss is : 7.50516
# Epoch 20 at batch 403 accuracy is : 0.898438
# Epoch 20 loss is : 13.2844
# Epoch 20 at batch 404 accuracy is : 0.898438
# Epoch 20 loss is : 7.09611
# Epoch 20 at batch 405 accuracy is : 0.898438
# Epoch 20 loss is : 16.678
# Epoch 20 at batch 406 accuracy is : 0.898438
# Epoch 20 loss is : 16.3087
# Epoch 20 at batch 407 accuracy is : 0.898438
# Epoch 20 loss is : 18.6615
# Epoch 20 at batch 408 accuracy is : 0.898438
# Epoch 20 loss is : 2.83993
# Epoch 20 at batch 409 accuracy is : 0.898438
# Epoch 20 loss is : 2.63856
# Epoch 20 at batch 410 accuracy is : 0.898438
# Epoch 20 loss is : 9.80619
# Epoch 20 at batch 411 accuracy is : 0.898438
# Epoch 20 loss is : 11.9154
# Epoch 20 at batch 412 accuracy is : 0.898438
# Epoch 20 loss is : 7.33923
# Epoch 20 at batch 413 accuracy is : 0.898438
# Epoch 20 loss is : 13.6136
# Epoch 20 at batch 414 accuracy is : 0.898438
# Epoch 20 loss is : 11.316
# Epoch 20 at batch 415 accuracy is : 0.898438
# Epoch 20 loss is : 13.2294
# Epoch 20 at batch 416 accuracy is : 0.898438
# Epoch 20 loss is : 10.3993
# Epoch 20 at batch 417 accuracy is : 0.898438
# Epoch 20 loss is : 7.67402
# Epoch 20 at batch 418 accuracy is : 0.898438
# Epoch 20 loss is : 11.8834
# Epoch 20 at batch 419 accuracy is : 0.898438
# Epoch 20 loss is : 8.68346
# Epoch 20 at batch 420 accuracy is : 0.898438
# Epoch 20 loss is : 13.2881
# Epoch 20 at batch 421 accuracy is : 0.898438
# Epoch 20 loss is : 9.37221
# Epoch 20 at batch 422 accuracy is : 0.898438
# Epoch 20 loss is : 4.86533
# Epoch 20 at batch 423 accuracy is : 0.898438
# Epoch 20 loss is : 10.8617
# Epoch 20 at batch 424 accuracy is : 0.898438
# Epoch 20 loss is : 3.25753
# Epoch 20 at batch 425 accuracy is : 0.898438
# Epoch 20 loss is : 12.7778
# Epoch 20 at batch 426 accuracy is : 0.898438
# Epoch 20 loss is : 6.23314
# Epoch 20 at batch 427 accuracy is : 0.898438
# Epoch 20 loss is : 7.84564
# Epoch 20 at batch 428 accuracy is : 0.898438
# Epoch 20 loss is : 3.75558
# Testing Accuracy: 0.9296875

# %% [markdown]
# ### Question 1
# _What approach did you take in coming up with a solution to this problem?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 2
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 3
# _How did you train your model? How did you generate your synthetic dataset?_ Include examples of images from the synthetic data you constructed.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ----
# ## Step 2: Train a Model on a Realistic Dataset
# Once you have settled on a good architecture, you can train your model on real data. In particular, the [Street View House Numbers (SVHN)](http://ufldl.stanford.edu/housenumbers/) dataset is a good large-scale dataset collected from house numbers in Google Street View. Training on this more challenging dataset, where the digits are not neatly lined-up and have various skews, fonts and colors, likely means you have to do some hyperparameter exploration to perform well.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your code implementation goes here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 4
# _Describe how you set up the training and testing data for your model. How does the model perform on a realistic dataset?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 5
# _What changes did you have to make, if any, to achieve "good" results? Were there any options you explored that made the results worse?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 6
# _What were your initial and final results with testing on a realistic dataset? Do you believe your model is doing a good enough job at classifying numbers correctly?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ----
# ## Step 3: Test a Model on Newly-Captured Images
#
# Take several pictures of numbers that you find around you (at least five), and run them through your classifier on your computer to produce example results. Alternatively (optionally), you can try using OpenCV / SimpleCV / Pygame to capture live images from a webcam and run those through your classifier.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your code implementation goes here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 7
# _Choose five candidate images of numbers you took from around you and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 8
# _Is your model able to perform equally well on captured pictures or a live camera stream when compared to testing on the realistic dataset?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Optional: Question 9
# _If necessary, provide documentation for how an interface was built for your model to load and classify newly-acquired images._

# %% [markdown]
# **Answer:** Leave blank if you did not complete this part.

# %% [markdown]
# ----
# ### Step 4: Explore an Improvement for a Model
#
# There are many things you can do once you have the basic classifier in place. One example would be to also localize where the numbers are on the image. The SVHN dataset provides bounding boxes that you can tune to train a localizer. Train a regression loss to the coordinates of the bounding box, and then test it.

# %% [markdown]
# ### Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your code implementation goes here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Question 10
# _How well does your model localize numbers on the testing set from the realistic dataset? Do your classification results change at all with localization included?_

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 11
# _Test the localization function on the images you captured in **Step 3**. Does the model accurately calculate a bounding box for the numbers in the images you found? If you did not use a graphical interface, you may need to investigate the bounding boxes by hand._ Provide an example of the localization created on a captured image.

# %% [markdown]
# **Answer:**

# %% [markdown]
# ----
# ## Optional Step 5: Build an Application or Program for a Model
# Take your project one step further. If you're interested, look to build an Android application or even a more robust Python program that can interface with input images and display the classified numbers and even the bounding boxes. You can for example try to build an augmented reality app by overlaying your answer on the image like the [Word Lens](https://en.wikipedia.org/wiki/Word_Lens) app does.
#
# Loading a TensorFlow model into a camera app on Android is demonstrated in the [TensorFlow Android demo app](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/android), which you can simply modify.
#
# If you decide to explore this optional route, be sure to document your interface and implementation, along with significant results you find. You can see the additional rubric items that you could be evaluated on by [following this link](https://review.udacity.com/#!/rubrics/413/view).

# %% [markdown]
# ### Optional Implementation
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Your optional code implementation goes here.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Documentation
# Provide additional documentation sufficient for detailing the implementation of the Android application or Python program for visualizing the classification of numbers in images. It should be clear how the program or application works. Demonstrations should be provided.

# %% [markdown]
# _Write your documentation here._

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
